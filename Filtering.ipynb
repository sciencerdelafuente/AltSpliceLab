# %%
import pandas as pd
import networkx as nx

refseq = pd.read_csv('assembly_summary_refseq.csv', header=1, sep='\t', low_memory=False)

refseq_assembly_level = refseq[refseq['assembly_level'] == 'Chromosome']

#--------------------Filters Eukaryotes----------------------
#Assembly Level
values = ['Chromosome','Complete Genome']
refseq_assembly_level = refseq[refseq['assembly_level'].isin(values)]
#Annotation Provider
refseq_assembly_level_NCBI = refseq_assembly_level[refseq_assembly_level['annotation_provider'] == 'NCBI RefSeq']
#Group
tax = ['invertebrate','vertebrate_mammalian','vertebrate_other','plant']
refseq_assembly_level_NCBI_group = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['group'].isin(tax)]



# Print 

#Columns of RefSeq
refseq.columns
refseq.iloc[:, refseq.columns.isin(['assembly_level','organism_name'])]
refseq.iloc[:10]
refseq_assembly_level.iloc[:10]
refseq.iloc[:10, refseq.columns.isin(['assembly_level','organism_name'])]
refseq_assembly_level.iloc[:10, refseq.columns.isin(['assembly_level','organism_name'])]
refseq_assembly_level_NCBI_group.iloc[180:200, refseq.columns.isin(['assembly_level','organism_name'])]
refseq_assembly_level_NCBI_group.iloc[180:200]
refseq.iloc[:20, refseq.columns.isin(['gbrs_paired_asm','organism_name','group'])]
#list(refseq_assembly_level_NCBI_group.columns)

#List of columns
#list(refseq_assembly_level_NCBI_group.columns)



#List of Taxonomical Groups in the column 'group'
refseq['group'].unique().tolist()
refseq_assembly_level_NCBI['group'].unique().tolist()
#Result: ['invertebrate','vertebrate_mammalian','plant','vertebrate_other','protozoa','fungi','bacteria','archaea','viral']



#Final list
refseq_assembly_level_NCBI.iloc[:20, refseq.columns.isin(['assembly_level','organism_name','group'])]
refseq_assembly_level_NCBI_group.iloc[:20, refseq.columns.isin(['assembly_level','organism_name','group'])]

#Save in a csv file
refseq_assembly_level_NCBI_group.to_csv('assembly_summary_refseq_Eukaryotes.csv', sep=" ")


#Names of species
names = refseq_assembly_level_NCBI_group['organism_name']
names.to_csv('organism_name.csv', sep=" ")

names.to_csv('organism_name.txt', sep=" ", index=False)




import copy
from io import StringIO

from Bio import Phylo
from Bio.Phylo.Applications import PhymlCommandline
from Bio.Phylo.PAML import codeml
from Bio.Phylo.PhyloXML import Phylogeny

tree = Phylo.read("phyliptree.phy", "newick")
print(tree)

common_ancestor_mammals = tree.clade[0,5,1]
common_ancestor_plants = tree.clade[1]
common_ancestor_arthropods = tree.clade[0,7]
common_ancestor_aves = tree.clade[0,5,2]
common_ancestor_fish = tree.clade[0,5,7]

term_names_mammals = [term.name for term in common_ancestor_mammals.get_terminals()]
term_names_plants = [term.name for term in common_ancestor_plants.get_terminals()]
term_names_arthropods = [term.name for term in common_ancestor_arthropods.get_terminals()]
term_names_aves = [term.name for term in common_ancestor_aves.get_terminals()]
term_names_fish = [term.name for term in common_ancestor_fish.get_terminals()]




term_names_mammals_df = pd.DataFrame([term_names_mammals])
term_names_mammals_df.to_csv('mammals.txt', sep='\t', index=False,header=None)

term_names_plants_df = pd.DataFrame([term_names_plants])
term_names_plants_df.to_csv('plants.txt', sep='\t', index=False,header=None)

term_names_arthropods_df = pd.DataFrame([term_names_arthropods])
term_names_arthropods_df.to_csv('arthropods.txt', sep='\t', index=False,header=None)

term_names_aves_df = pd.DataFrame([term_names_aves])
term_names_aves_df.to_csv('aves.txt', sep='\t', index=False,header=None)

term_names_fish_df = pd.DataFrame([term_names_fish])
term_names_fish_df.to_csv('fish.txt', sep='\t', index=False,header=None)





#1. RefSeq Group & Remove duplicated species & Add a Taxonomy Group
refseq_mammals = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['organism_name'].isin(term_names_mammals)]
refseq_mammals = refseq_mammals.drop_duplicates(subset=['organism_name'], keep='last')

refseq_plants = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['organism_name'].isin(term_names_plants)]
refseq_plants = refseq_plants.drop_duplicates(subset=['organism_name'], keep='last')


refseq_arthropods = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['organism_name'].isin(term_names_arthropods)]
refseq_arthropods = refseq_arthropods.drop_duplicates(subset=['organism_name'], keep='last')


refseq_aves = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['organism_name'].isin(term_names_aves)]
refseq_aves = refseq_aves.drop_duplicates(subset=['organism_name'], keep='last')


refseq_fish = refseq_assembly_level_NCBI[refseq_assembly_level_NCBI['organism_name'].isin(term_names_fish)]
refseq_fish = refseq_fish.drop_duplicates(subset=['organism_name'], keep='last')


#Assign a column with a new Taxonomical classification
list = ['Fish'] * len(refseq_fish)
refseq_fish=refseq_fish.assign(Taxonomy=list)

list = ['Arthropods'] * len(refseq_arthropods)
refseq_arthropods=refseq_arthropods.assign(Taxonomy=list)

list = ['Plants'] * len(refseq_plants)
refseq_plants=refseq_plants.assign(Taxonomy=list)

list = ['Mammals'] * len(refseq_mammals)
refseq_mammals=refseq_mammals.assign(Taxonomy=list)

list = ['Birds'] * len(refseq_aves)
refseq_aves=refseq_aves.assign(Taxonomy=list)

#Merge all eukaryotes in a file
refseq_eukaryotes = pd.concat([refseq_mammals, refseq_aves, refseq_arthropods, refseq_fish, refseq_plants], axis=0)


#Save in a csv file
refseq_eukaryotes.to_csv('Refseq_Eukaryotes.csv', sep='\t')






#----------------Other Taxonomical Groups
#Group Level
refseq_fungi = refseq[refseq['group'] == 'fungi']
refseq_protozoa = refseq[refseq['group'] == 'protozoa']
refseq_bacteria = refseq[refseq['group'] == 'bacteria']
refseq_archaea = refseq[refseq['group'] == 'archaea']


#Assembly Level
values = ['Chromosome','Complete Genome']
refseq_fungi_assembly = refseq_fungi[refseq_fungi['assembly_level'].isin(values)]
refseq_protozoa_assembly = refseq_protozoa[refseq_protozoa['assembly_level'].isin(values)]
refseq_bacteria_assembly = refseq_bacteria[refseq_bacteria['assembly_level'].isin(values)]
refseq_archaea_assembly = refseq_archaea[refseq_archaea['assembly_level'].isin(values)]

#Annotation Provider
refseq_fungi_assembly_annotation=refseq_fungi_assembly

refseq_protozoa_assembly_annotation = refseq_protozoa_assembly[refseq_protozoa_assembly['annotation_provider'] == 'NCBI RefSeq']
refseq_protozoa_assembly.iloc[:50, refseq.columns.isin(['annotation_name','annotation_provider'])]

refseq_bacteria_assembly_annotation = refseq_bacteria_assembly[refseq_bacteria_assembly['annotation_provider'] == 'NCBI RefSeq']
refseq_bacteria_assembly_annotation = refseq_bacteria_assembly_annotation[refseq_bacteria_assembly_annotation['annotation_name'] == 'NCBI Prokaryotic Genome Annotation Pipeline (PGAP)']

refseq_archaea_assembly_annotation = refseq_archaea_assembly[refseq_archaea_assembly['annotation_provider'] == 'NCBI RefSeq']
refseq_archaea_assembly_annotation = refseq_archaea_assembly_annotation[refseq_archaea_assembly_annotation['annotation_name'] == 'NCBI Prokaryotic Genome Annotation Pipeline (PGAP)']


#Nos quedamos con el filtro de "assembly". Nos quedamos con 200 elementos de bacteria y de archaea
refseq_bacteria_assembly_f = refseq_bacteria_assembly.iloc[:400]
refseq_archaea_assembly_f = refseq_archaea_assembly.iloc[:400]
refseq_protozoa_assembly_f = refseq_protozoa_assembly
refseq_fungi_assembly_f = refseq_fungi_assembly


#Assign New Taxonomical Groups
list = ['Fungi'] * len(refseq_fungi_assembly_f)
refseq_fungi_assembly_f=refseq_fungi_assembly_f.assign(Taxonomy=list)

list = ['Unicellular Eukaryotes'] * len(refseq_protozoa_assembly_f)
refseq_protozoa_assembly_f=refseq_protozoa_assembly_f.assign(Taxonomy=list)

list = ['Bacteria'] * len(refseq_bacteria_assembly_f)
refseq_bacteria_assembly_f=refseq_bacteria_assembly_f.assign(Taxonomy=list)

list = ['Archaea'] * len(refseq_archaea_assembly_f)
refseq_archaea_assembly_f=refseq_archaea_assembly_f.assign(Taxonomy=list)


#Escribimos en un archivo
refseq_fungi_assembly_f.to_csv('Refseq_Fungi.csv', sep='\t')
refseq_protozoa_assembly_f.to_csv('Refseq_UnicellularEukaryotes.csv', sep='\t')
refseq_bacteria_assembly_f.to_csv('Refseq_Bacteria.csv', sep='\t')
refseq_archaea_assembly_f.to_csv('Refseq_Archaea.csv', sep='\t')
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade(branch_length=4.0, name='Eukaryota')
#         Clade(branch_length=4.0, name='Metazoa')
#             Clade(branch_length=4.0, name='Gordionus sp. m RMFG-2023')
#             Clade(branch_length=4.0, name='Bolinopsis microptera')
#             Clade(branch_length=4.0, name='Watersipora subatra')
#             Clade(branch_length=4.0, name='Lineus longissimus')
#             Clade(branch_length=4.0, name='Symsagittifera roscoffensis')
#             Clade(branch_length=4.0, name='Chordata')
#                 Clade(branch_length=4.0, name='Polypteriformes')
#                     Clade(branch_length=4.0, name='Polypterus senegalus')
#                     Clade(branch_length=4.0, name='Erpetoichthys calabaricus')
#                 Clade(branch_length=4.0, name='Mammalia')
#                     Clade(branch_length=4.0, name='Manis pentadactyla')
#                     Clade(branch_length=4.0, name='Cynocephalus volans')
#                     Clade(branch_length=4.0, name='Dromiciops gliroides')
#                     Clade(branch_length=4.0, name='Choloepus didactylus')
#                     Clade(branch_length=4.0, name='Didelphimorphia')
#                         Clade(branch_length=4.0, name='Gracilinanus agilis')
#                         Clade(branch_length=4.0, name='Monodelphis domestica')
#                     Clade(branch_length=4.0, name='Rodentia')
#                         Clade(branch_length=4.0, name='Arvicola amphibius')
#                         Clade(branch_length=4.0, name='Chionomys nivalis')
#                         Clade(branch_length=4.0, name='Peromyscus maniculatus bairdii')
#                         Clade(branch_length=4.0, name='Perognathus longimembris pacificus')
#                         Clade(branch_length=4.0, name='Microtus ochrogaster')
#                         Clade(branch_length=4.0, name='Arvicanthis niloticus')
#                         Clade(branch_length=4.0, name='Acomys russatus')
#                         Clade(branch_length=4.0, name='Jaculus jaculus')
#                         Clade(branch_length=4.0, name='Ictidomys tridecemlineatus')
#                         Clade(branch_length=4.0, name='Peromyscus eremicus')
#                         Clade(branch_length=4.0, name='Onychomys torridus')
#                         Clade(branch_length=4.0, name='Mastomys coucha')
#                         Clade(branch_length=4.0, name='Sciurus carolinensis')
#                         Clade(branch_length=4.0, name='Apodemus sylvaticus')
#                         Clade(branch_length=4.0, name='Rattus rattus')
#                         Clade(branch_length=4.0, name='Rattus norvegicus')
#                         Clade(branch_length=4.0, name='Mus pahari')
#                         Clade(branch_length=4.0, name='Mus musculus')
#                         Clade(branch_length=4.0, name='Mus caroli')
#                         Clade(branch_length=4.0, name='Meriones unguiculatus')
#                         Clade(branch_length=4.0, name='Peromyscus leucopus')
#                         Clade(branch_length=4.0, name='Cricetulus griseus')
#                     Clade(branch_length=4.0, name='Lagomorpha')
#                         Clade(branch_length=4.0, name='Oryctolagus cuniculus')
#                         Clade(branch_length=4.0, name='Lepus europaeus')
#                         Clade(branch_length=4.0, name='Ochotona princeps')
#                     Clade(branch_length=4.0, name='Perissodactyla')
#                         Clade(branch_length=4.0, name='Equus quagga')
#                         Clade(branch_length=4.0, name='Diceros bicornis minor')
#                         Clade(branch_length=4.0, name='Equus caballus')
#                         Clade(branch_length=4.0, name='Equus asinus')
#                     Clade(branch_length=4.0, name='Proboscidea')
#                         Clade(branch_length=4.0, name='Elephas maximus indicus')
#                         Clade(branch_length=4.0, name='Loxodonta africana')
#                     Clade(branch_length=4.0, name='Artiodactyla')
#                         Clade(branch_length=4.0, name='Bubalus kerabau')
#                         Clade(branch_length=4.0, name='Balaenoptera ricei')
#                         Clade(branch_length=4.0, name='Cervus canadensis')
#                         Clade(branch_length=4.0, name='Hippopotamus amphibius kiboko')
#                         Clade(branch_length=4.0, name='Camelus ferus')
#                         Clade(branch_length=4.0, name='Bubalus bubalis')
#                         Clade(branch_length=4.0, name='Pseudorca crassidens')
#                         Clade(branch_length=4.0, name='Mesoplodon densirostris')
#                         Clade(branch_length=4.0, name='Phocoena sinus')
#                         Clade(branch_length=4.0, name='Phacochoerus africanus')
#                         Clade(branch_length=4.0, name='Budorcas taxicolor')
#                         Clade(branch_length=4.0, name='Capricornis sumatraensis')
#                         Clade(branch_length=4.0, name='Dama dama')
#                         Clade(branch_length=4.0, name='Bos indicus x Bos taurus')
#                         Clade(branch_length=4.0, name='Kogia breviceps')
#                         Clade(branch_length=4.0, name='Lagenorhynchus albirostris')
#                         Clade(branch_length=4.0, name='Eubalaena glacialis')
#                         Clade(branch_length=4.0, name='Ovis aries')
#                         Clade(branch_length=4.0, name='Capra hircus')
#                         Clade(branch_length=4.0, name='Bos indicus')
#                         Clade(branch_length=4.0, name='Bos taurus')
#                         Clade(branch_length=4.0, name='Bos javanicus')
#                         Clade(branch_length=4.0, name='Muntiacus reevesi')
#                         Clade(branch_length=4.0, name='Cervus elaphus')
#                         Clade(branch_length=4.0, name='Camelus dromedarius')
#                         Clade(branch_length=4.0, name='Sus scrofa')
#                         Clade(branch_length=4.0, name='Balaenoptera musculus')
#                         Clade(branch_length=4.0, name='Balaenoptera acutorostrata')
#                         Clade(branch_length=4.0, name='Eschrichtius robustus')
#                         Clade(branch_length=4.0, name='Physeter catodon')
#                         Clade(branch_length=4.0, name='Phocoena phocoena')
#                         Clade(branch_length=4.0, name='Tursiops truncatus')
#                         Clade(branch_length=4.0, name='Orcinus orca')
#                         Clade(branch_length=4.0, name='Globicephala melas')
#                         Clade(branch_length=4.0, name='Delphinus delphis')
#                     Clade(branch_length=4.0, name='Carnivora')
#                         Clade(branch_length=4.0, name='Vulpes lagopus')
#                         Clade(branch_length=4.0, name='Neogale vison')
#                         Clade(branch_length=4.0, name='Mustela nigripes')
#                         Clade(branch_length=4.0, name='Neofelis nebulosa')
#                         Clade(branch_length=4.0, name='Prionailurus viverrinus')
#                         Clade(branch_length=4.0, name='Lynx canadensis')
#                         Clade(branch_length=4.0, name='Leopardus geoffroyi')
#                         Clade(branch_length=4.0, name='Suricata suricatta')
#                         Clade(branch_length=4.0, name='Prionailurus bengalensis')
#                         Clade(branch_length=4.0, name='Mustela erminea')
#                         Clade(branch_length=4.0, name='Acinonyx jubatus')
#                         Clade(branch_length=4.0, name='Neomonachus schauinslandi')
#                         Clade(branch_length=4.0, name='Panthera uncia')
#                         Clade(branch_length=4.0, name='Zalophus californianus')
#                         Clade(branch_length=4.0, name='Panthera tigris')
#                         Clade(branch_length=4.0, name='Panthera onca')
#                         Clade(branch_length=4.0, name='Panthera leo')
#                         Clade(branch_length=4.0, name='Felis catus')
#                         Clade(branch_length=4.0, name='Mustela lutreola')
#                         Clade(branch_length=4.0, name='Meles meles')
#                         Clade(branch_length=4.0, name='Lutra lutra')
#                         Clade(branch_length=4.0, name='Ailuropoda melanoleuca')
#                         Clade(branch_length=4.0, name='Ursus arctos')
#                         Clade(branch_length=4.0, name='Canis lupus')
#                             Clade(branch_length=4.0, name='Canis lupus dingo')
#                             Clade(branch_length=4.0, name='Canis lupus familiaris')
#                     Clade(branch_length=4.0, name='Primates')
#                         Clade(branch_length=4.0, name='Eulemur rufifrons')
#                         Clade(branch_length=4.0, name='Piliocolobus tephrosceles')
#                         Clade(branch_length=4.0, name='Macaca thibetana thibetana')
#                         Clade(branch_length=4.0, name='Nomascus leucogenys')
#                         Clade(branch_length=4.0, name='Rhinopithecus roxellana')
#                         Clade(branch_length=4.0, name='Microcebus murinus')
#                         Clade(branch_length=4.0, name='Homo sapiens')
#                         Clade(branch_length=4.0, name='Pongo abelii')
#                         Clade(branch_length=4.0, name='Pongo pygmaeus')
#                         Clade(branch_length=4.0, name='Pan troglodytes')
#                         Clade(branch_length=4.0, name='Pan paniscus')
#                         Clade(branch_length=4.0, name='Gorilla gorilla gorilla')
#                         Clade(branch_length=4.0, name='Symphalangus syndactylus')
#                         Clade(branch_length=4.0, name='Theropithecus gelada')
#                         Clade(branch_length=4.0, name='Papio anubis')
#                         Clade(branch_length=4.0, name='Macaca mulatta')
#                         Clade(branch_length=4.0, name='Macaca fascicularis')
#                         Clade(branch_length=4.0, name='Callithrix jacchus')
#                         Clade(branch_length=4.0, name='Nycticebus coucang')
#                         Clade(branch_length=4.0, name='Lemur catta')
#                     Clade(branch_length=4.0, name='Chiroptera')
#                         Clade(branch_length=4.0, name='Saccopteryx leptura')
#                         Clade(branch_length=4.0, name='Myotis daubentonii')
#                         Clade(branch_length=4.0, name='Phyllostomus discolor')
#                         Clade(branch_length=4.0, name='Saccopteryx bilineata')
#                         Clade(branch_length=4.0, name='Rhinolophus ferrumequinum')
#                         Clade(branch_length=4.0, name='Eptesicus fuscus')
#                         Clade(branch_length=4.0, name='Desmodus rotundus')
#                     Clade(branch_length=4.0, name='Eulipotyphla')
#                         Clade(branch_length=4.0, name='Suncus etruscus')
#                         Clade(branch_length=4.0, name='Sorex araneus')
#                         Clade(branch_length=4.0, name='Erinaceus europaeus')
#                     Clade(branch_length=4.0, name='Dasypus novemcinctus')
#                     Clade(branch_length=4.0, name='Trichosurus vulpecula')
#                     Clade(branch_length=4.0, name='Dasyuromorphia')
#                         Clade(branch_length=4.0, name='Antechinus flavipes')
#                         Clade(branch_length=4.0, name='Sarcophilus harrisii')
#                     Clade(branch_length=4.0, name='Monotremata')
#                         Clade(branch_length=4.0, name='Tachyglossus aculeatus')
#                         Clade(branch_length=4.0, name='Ornithorhynchus anatinus')
#                 Clade(branch_length=4.0, name='Aves')
#                     Clade(branch_length=4.0, name='Apteryx mantelli')
#                     Clade(branch_length=4.0, name='Piciformes')
#                         Clade(branch_length=4.0, name='Indicator indicator')
#                         Clade(branch_length=4.0, name='Pogoniulus pusillus')
#                         Clade(branch_length=4.0, name='Dryobates pubescens')
#                     Clade(branch_length=4.0, name='Charadriiformes')
#                         Clade(branch_length=4.0, name='Chroicocephalus ridibundus')
#                         Clade(branch_length=4.0, name='Rissa tridactyla')
#                     Clade(branch_length=4.0, name='Colius striatus')
#                     Clade(branch_length=4.0, name='Cuculus canorus')
#                     Clade(branch_length=4.0, name='Nyctibius grandis')
#                     Clade(branch_length=4.0, name='Gavia stellata')
#                     Clade(branch_length=4.0, name='Psittaciformes')
#                         Clade(branch_length=4.0, name='Strigops habroptila')
#                         Clade(branch_length=4.0, name='Lathamus discolor')
#                         Clade(branch_length=4.0, name='Melopsittacus undulatus')
#                     Clade(branch_length=4.0, name='Phalacrocorax carbo')
#                     Clade(branch_length=4.0, name='Passeriformes')
#                         Clade(branch_length=4.0, name='Oenanthe melanoleuca')
#                         Clade(branch_length=4.0, name='Ammospiza caudacuta')
#                         Clade(branch_length=4.0, name='Ammospiza nelsoni')
#                         Clade(branch_length=4.0, name='Melospiza melodia melodia')
#                         Clade(branch_length=4.0, name='Corvus moneduloides')
#                         Clade(branch_length=4.0, name='Motacilla alba alba')
#                         Clade(branch_length=4.0, name='Corvus cornix cornix')
#                         Clade(branch_length=4.0, name='Pseudopipra pipra')
#                         Clade(branch_length=4.0, name='Chiroxiphia lanceolata')
#                         Clade(branch_length=4.0, name='Zonotrichia leucophrys gambelii')
#                         Clade(branch_length=4.0, name='Prinia subflava')
#                         Clade(branch_length=4.0, name='Vidua macroura')
#                         Clade(branch_length=4.0, name='Anomalospiza imberbis')
#                         Clade(branch_length=4.0, name='Corvus hawaiiensis')
#                         Clade(branch_length=4.0, name='Cinclus cinclus')
#                         Clade(branch_length=4.0, name='Catharus ustulatus')
#                         Clade(branch_length=4.0, name='Camarhynchus parvulus')
#                         Clade(branch_length=4.0, name='Molothrus ater')
#                         Clade(branch_length=4.0, name='Molothrus aeneus')
#                         Clade(branch_length=4.0, name='Vidua chalybeata')
#                         Clade(branch_length=4.0, name='Ficedula albicollis')
#                         Clade(branch_length=4.0, name='Taeniopygia guttata')
#                         Clade(branch_length=4.0, name='Poecile atricapillus')
#                         Clade(branch_length=4.0, name='Passer domesticus')
#                         Clade(branch_length=4.0, name='Sylvia atricapilla')
#                         Clade(branch_length=4.0, name='Melospiza georgiana')
#                         Clade(branch_length=4.0, name='Hirundo rustica')
#                         Clade(branch_length=4.0, name='Lonchura striata')
#                         Clade(branch_length=4.0, name='Agelaius phoeniceus')
#                         Clade(branch_length=4.0, name='Aphelocoma coerulescens')
#                         Clade(branch_length=4.0, name='Haemorhous mexicanus')
#                         Clade(branch_length=4.0, name='Parus major')
#                         Clade(branch_length=4.0, name='Serinus canaria')
#                     Clade(branch_length=4.0, name='Grus americana')
#                     Clade(branch_length=4.0, name='Galliformes')
#                         Clade(branch_length=4.0, name='Coturnix japonica')
#                         Clade(branch_length=4.0, name='Lagopus muta')
#                         Clade(branch_length=4.0, name='Meleagris gallopavo')
#                         Clade(branch_length=4.0, name='Gallus gallus')
#                         Clade(branch_length=4.0, name='Numida meleagris')
#                     Clade(branch_length=4.0, name='Accipitriformes')
#                         Clade(branch_length=4.0, name='Aquila chrysaetos chrysaetos')
#                         Clade(branch_length=4.0, name='Harpia harpyja')
#                         Clade(branch_length=4.0, name='Gymnogyps californianus')
#                         Clade(branch_length=4.0, name='Accipiter gentilis')
#                     Clade(branch_length=4.0, name='Falconiformes')
#                         Clade(branch_length=4.0, name='Falco cherrug')
#                         Clade(branch_length=4.0, name='Falco biarmicus')
#                         Clade(branch_length=4.0, name='Falco naumanni')
#                         Clade(branch_length=4.0, name='Falco rusticolus')
#                         Clade(branch_length=4.0, name='Falco peregrinus')
#                     Clade(branch_length=4.0, name='Columbiformes')
#                         Clade(branch_length=4.0, name='Patagioenas fasciata')
#                         Clade(branch_length=4.0, name='Caloenas nicobarica')
#                         Clade(branch_length=4.0, name='Columba livia')
#                     Clade(branch_length=4.0, name='Apodiformes')
#                         Clade(branch_length=4.0, name='Calypte anna')
#                         Clade(branch_length=4.0, name='Apus apus')
#                     Clade(branch_length=4.0, name='Anseriformes')
#                         Clade(branch_length=4.0, name='Aythya fuligula')
#                         Clade(branch_length=4.0, name='Anas acuta')
#                         Clade(branch_length=4.0, name='Oxyura jamaicensis')
#                         Clade(branch_length=4.0, name='Cygnus olor')
#                         Clade(branch_length=4.0, name='Cygnus atratus')
#                         Clade(branch_length=4.0, name='Anser cygnoides')
#                         Clade(branch_length=4.0, name='Anas platyrhynchos')
#                     Clade(branch_length=4.0, name='Struthio camelus')
#                     Clade(branch_length=4.0, name='Rhea pennata')
#                     Clade(branch_length=4.0, name='Dromaius novaehollandiae')
#                 Clade(branch_length=4.0, name='Squamata')
#                     Clade(branch_length=4.0, name='Sphaerodactylus townsendi')
#                     Clade(branch_length=4.0, name='Hemicordylus capensis')
#                     Clade(branch_length=4.0, name='Ahaetulla prasina')
#                     Clade(branch_length=4.0, name='Eublepharis macularius')
#                     Clade(branch_length=4.0, name='Euleptes europaea')
#                     Clade(branch_length=4.0, name='Rhineura floridana')
#                     Clade(branch_length=4.0, name='Elgaria multicarinata webbii')
#                     Clade(branch_length=4.0, name='Lacerta agilis')
#                     Clade(branch_length=4.0, name='Tiliqua scincoides')
#                     Clade(branch_length=4.0, name='Podarcis raffonei')
#                     Clade(branch_length=4.0, name='Podarcis muralis')
#                     Clade(branch_length=4.0, name='Candoia aspera')
#                     Clade(branch_length=4.0, name='Anolis sagrei')
#                     Clade(branch_length=4.0, name='Thamnophis elegans')
#                     Clade(branch_length=4.0, name='Anolis carolinensis')
#                     Clade(branch_length=4.0, name='Heteronotia binoei')
#                     Clade(branch_length=4.0, name='Zootoca vivipara')
#                     Clade(branch_length=4.0, name='Sceloporus undulatus')
#                 Clade(branch_length=4.0, name='Alligator mississippiensis')
#                 Clade(branch_length=4.0, name='Testudines')
#                     Clade(branch_length=4.0, name='Malaclemys terrapin pileata')
#                     Clade(branch_length=4.0, name='Gopherus evgoodei')
#                     Clade(branch_length=4.0, name='Gopherus flavomarginatus')
#                     Clade(branch_length=4.0, name='Mauremys reevesii')
#                     Clade(branch_length=4.0, name='Emys orbicularis')
#                     Clade(branch_length=4.0, name='Mauremys mutica')
#                     Clade(branch_length=4.0, name='Trachemys scripta elegans')
#                     Clade(branch_length=4.0, name='Dermochelys coriacea')
#                     Clade(branch_length=4.0, name='Chrysemys picta bellii')
#                     Clade(branch_length=4.0, name='Chelonia mydas')
#                     Clade(branch_length=4.0, name='Caretta caretta')
#                 Clade(branch_length=4.0, name='Amphibia')
#                     Clade(branch_length=4.0, name='Gymnophiona')
#                         Clade(branch_length=4.0, name='Microcaecilia unicolor')
#                         Clade(branch_length=4.0, name='Geotrypetes seraphini')
#                         Clade(branch_length=4.0, name='Rhinatrema bivittatum')
#                     Clade(branch_length=4.0, name='Anura')
#                         Clade(branch_length=4.0, name='Hyperolius riggenbachi')
#                         Clade(branch_length=4.0, name='Pseudophryne corroboree')
#                         Clade(branch_length=4.0, name='Hyla sarda')
#                         Clade(branch_length=4.0, name='Spea bombifrons')
#                         Clade(branch_length=4.0, name='Pelobates fuscus')
#                         Clade(branch_length=4.0, name='Eleutherodactylus coqui')
#                         Clade(branch_length=4.0, name='Bufo gargarizans')
#                         Clade(branch_length=4.0, name='Rana temporaria')
#                         Clade(branch_length=4.0, name='Bufo bufo')
#                         Clade(branch_length=4.0, name='Xenopus tropicalis')
#                         Clade(branch_length=4.0, name='Xenopus laevis')
#                         Clade(branch_length=4.0, name='Bombina bombina')
#                     Clade(branch_length=4.0, name='Pleurodeles waltl')
#                 Clade(branch_length=4.0, name='Actinopteri')
#                     Clade(branch_length=4.0, name='Lampris incognitus')
#                     Clade(branch_length=4.0, name='Melanotaenia boesemani')
#                     Clade(branch_length=4.0, name='Toxotes jaculatrix')
#                     Clade(branch_length=4.0, name='Myripristis murdjan')
#                     Clade(branch_length=4.0, name='Periophthalmus magnuspinnatus')
#                     Clade(branch_length=4.0, name='Thalassophryne amazonica')
#                     Clade(branch_length=4.0, name='Sphaeramia orbicularis')
#                     Clade(branch_length=4.0, name='Lophiiformes')
#                         Clade(branch_length=4.0, name='Brachionichthys hirsutus')
#                         Clade(branch_length=4.0, name='Antennarius striatus')
#                     Clade(branch_length=4.0, name='Larimichthys crocea')
#                     Clade(branch_length=4.0, name='Parambassis ranga')
#                     Clade(branch_length=4.0, name='Mastacembelus armatus')
#                     Clade(branch_length=4.0, name='Blenniiformes')
#                         Clade(branch_length=4.0, name='Gouania willdenowi')
#                         Clade(branch_length=4.0, name='Salarias fasciatus')
#                     Clade(branch_length=4.0, name='Carangiformes')
#                         Clade(branch_length=4.0, name='Seriola aureovittata')
#                         Clade(branch_length=4.0, name='Echeneis naucrates')
#                     Clade(branch_length=4.0, name='Centrarchiformes')
#                         Clade(branch_length=4.0, name='Micropterus dolomieu')
#                         Clade(branch_length=4.0, name='Siniperca chuatsi')
#                     Clade(branch_length=4.0, name='Megalops cyprinoides')
#                     Clade(branch_length=4.0, name='Chelmon rostratus')
#                     Clade(branch_length=4.0, name='Syngnathiformes')
#                         Clade(branch_length=4.0, name='Phycodurus eques')
#                         Clade(branch_length=4.0, name='Syngnathoides biaculeatus')
#                         Clade(branch_length=4.0, name='Synchiropus splendidus')
#                         Clade(branch_length=4.0, name='Syngnathus typhle')
#                         Clade(branch_length=4.0, name='Syngnathus scovelli')
#                         Clade(branch_length=4.0, name='Syngnathus acus')
#                         Clade(branch_length=4.0, name='Phyllopteryx taeniolatus')
#                         Clade(branch_length=4.0, name='Entelurus aequoreus')
#                         Clade(branch_length=4.0, name='Dunckerocampus dactyliophorus')
#                         Clade(branch_length=4.0, name='Doryrhamphus excisus')
#                         Clade(branch_length=4.0, name='Corythoichthys intestinalis')
#                         Clade(branch_length=4.0, name='Nerophis ophidion')
#                         Clade(branch_length=4.0, name='Hippocampus zosterae')
#                     Clade(branch_length=4.0, name='Amphiprion ocellaris')
#                     Clade(branch_length=4.0, name='Acanthochromis polyacanthus')
#                     Clade(branch_length=4.0, name='Scatophagus argus')
#                     Clade(branch_length=4.0, name='Anabantiformes')
#                         Clade(branch_length=4.0, name='Channa argus')
#                         Clade(branch_length=4.0, name='Betta splendens')
#                         Clade(branch_length=4.0, name='Anabas testudineus')
#                     Clade(branch_length=4.0, name='Labriformes')
#                         Clade(branch_length=4.0, name='Notolabrus celidotus')
#                         Clade(branch_length=4.0, name='Labrus mixtus')
#                         Clade(branch_length=4.0, name='Cheilinus undulatus')
#                         Clade(branch_length=4.0, name='Labrus bergylta')
#                     Clade(branch_length=4.0, name='Mugil cephalus')
#                     Clade(branch_length=4.0, name='Osteoglossiformes')
#                         Clade(branch_length=4.0, name='Scleropages formosus')
#                         Clade(branch_length=4.0, name='Brienomyrus brachyistius')
#                     Clade(branch_length=4.0, name='Tetraodontiformes')
#                         Clade(branch_length=4.0, name='Takifugu flavidus')
#                         Clade(branch_length=4.0, name='Takifugu rubripes')
#                     Clade(branch_length=4.0, name='Chanos chanos')
#                     Clade(branch_length=4.0, name='Pleuronectiformes')
#                         Clade(branch_length=4.0, name='Cynoglossus semilaevis')
#                         Clade(branch_length=4.0, name='Hippoglossus stenolepis')
#                         Clade(branch_length=4.0, name='Solea solea')
#                         Clade(branch_length=4.0, name='Scophthalmus maximus')
#                         Clade(branch_length=4.0, name='Solea senegalensis')
#                         Clade(branch_length=4.0, name='Limanda limanda')
#                         Clade(branch_length=4.0, name='Hippoglossus hippoglossus')
#                         Clade(branch_length=4.0, name='Pleuronectes platessa')
#                         Clade(branch_length=4.0, name='Platichthys flesus')
#                     Clade(branch_length=4.0, name='Xiphias gladius')
#                     Clade(branch_length=4.0, name='Scombriformes')
#                         Clade(branch_length=4.0, name='Scomber scombrus')
#                         Clade(branch_length=4.0, name='Scomber japonicus')
#                         Clade(branch_length=4.0, name='Thunnus maccoyii')
#                         Clade(branch_length=4.0, name='Thunnus thynnus')
#                         Clade(branch_length=4.0, name='Thunnus albacares')
#                     Clade(branch_length=4.0, name='Lates calcarifer')
#                     Clade(branch_length=4.0, name='Spariformes')
#                         Clade(branch_length=4.0, name='Acanthopagrus latus')
#                         Clade(branch_length=4.0, name='Sparus aurata')
#                     Clade(branch_length=4.0, name='Cichliformes')
#                         Clade(branch_length=4.0, name='Pelmatolapia mariae')
#                         Clade(branch_length=4.0, name='Maylandia zebra')
#                         Clade(branch_length=4.0, name='Archocentrus centrarchus')
#                         Clade(branch_length=4.0, name='Oreochromis aureus')
#                         Clade(branch_length=4.0, name='Astatotilapia calliptera')
#                         Clade(branch_length=4.0, name='Oreochromis niloticus')
#                     Clade(branch_length=4.0, name='Perciformes')
#                         Clade(branch_length=4.0, name='Pseudoliparis swirei')
#                         Clade(branch_length=4.0, name='Gasterosteus aculeatus aculeatus')
#                         Clade(branch_length=4.0, name='Etheostoma cragini')
#                         Clade(branch_length=4.0, name='Epinephelus lanceolatus')
#                         Clade(branch_length=4.0, name='Epinephelus moara')
#                         Clade(branch_length=4.0, name='Epinephelus fuscoguttatus')
#                         Clade(branch_length=4.0, name='Sander lucioperca')
#                         Clade(branch_length=4.0, name='Anoplopoma fimbria')
#                         Clade(branch_length=4.0, name='Centropristis striata')
#                         Clade(branch_length=4.0, name='Plectropomus leopardus')
#                         Clade(branch_length=4.0, name='Pungitius pungitius')
#                         Clade(branch_length=4.0, name='Sebastes umbrosus')
#                         Clade(branch_length=4.0, name='Eleginops maclovinus')
#                         Clade(branch_length=4.0, name='Cottoperca gobio')
#                         Clade(branch_length=4.0, name='Etheostoma spectabile')
#                         Clade(branch_length=4.0, name='Pseudochaenichthys georgianus')
#                         Clade(branch_length=4.0, name='Perca fluviatilis')
#                         Clade(branch_length=4.0, name='Perca flavescens')
#                         Clade(branch_length=4.0, name='Cyclopterus lumpus')
#                     Clade(branch_length=4.0, name='Beloniformes')
#                         Clade(branch_length=4.0, name='Cololabis saira')
#                         Clade(branch_length=4.0, name='Oryzias melastigma')
#                         Clade(branch_length=4.0, name='Oryzias latipes')
#                     Clade(branch_length=4.0, name='Cyprinodontiformes')
#                         Clade(branch_length=4.0, name='Nematolebias whitei')
#                         Clade(branch_length=4.0, name='Girardinichthys multiradiatus')
#                         Clade(branch_length=4.0, name='Kryptolebias marmoratus')
#                         Clade(branch_length=4.0, name='Gambusia affinis')
#                         Clade(branch_length=4.0, name='Xiphophorus couchianus')
#                         Clade(branch_length=4.0, name='Xiphophorus hellerii')
#                         Clade(branch_length=4.0, name='Xiphophorus maculatus')
#                         Clade(branch_length=4.0, name='Poecilia reticulata')
#                         Clade(branch_length=4.0, name='Fundulus heteroclitus')
#                     Clade(branch_length=4.0, name='Gadiformes')
#                         Clade(branch_length=4.0, name='Gadus chalcogrammus')
#                         Clade(branch_length=4.0, name='Gadus macrocephalus')
#                         Clade(branch_length=4.0, name='Gadus morhua')
#                     Clade(branch_length=4.0, name='Salmoniformes')
#                         Clade(branch_length=4.0, name='Salvelinus sp. IW2-2015')
#                         Clade(branch_length=4.0, name='Oncorhynchus masou masou')
#                         Clade(branch_length=4.0, name='Oncorhynchus tshawytscha')
#                         Clade(branch_length=4.0, name='Coregonus clupeaformis')
#                         Clade(branch_length=4.0, name='Salvelinus namaycush')
#                         Clade(branch_length=4.0, name='Salvelinus fontinalis')
#                         Clade(branch_length=4.0, name='Salmo trutta')
#                         Clade(branch_length=4.0, name='Salmo salar')
#                         Clade(branch_length=4.0, name='Oncorhynchus nerka')
#                         Clade(branch_length=4.0, name='Oncorhynchus mykiss')
#                         Clade(branch_length=4.0, name='Oncorhynchus kisutch')
#                         Clade(branch_length=4.0, name='Oncorhynchus keta')
#                         Clade(branch_length=4.0, name='Oncorhynchus gorbuscha')
#                     Clade(branch_length=4.0, name='Osmeriformes')
#                         Clade(branch_length=4.0, name='Hypomesus transpacificus')
#                         Clade(branch_length=4.0, name='Osmerus eperlanus')
#                         Clade(branch_length=4.0, name='Osmerus mordax')
#                     Clade(branch_length=4.0, name='Esox lucius')
#                     Clade(branch_length=4.0, name='Electrophorus electricus')
#                     Clade(branch_length=4.0, name='Siluriformes')
#                         Clade(branch_length=4.0, name='Trichomycterus rosablanca')
#                         Clade(branch_length=4.0, name='Tachysurus fulvidraco')
#                         Clade(branch_length=4.0, name='Neoarius graeffei')
#                         Clade(branch_length=4.0, name='Hemibagrus wyckioides')
#                         Clade(branch_length=4.0, name='Pangasianodon hypophthalmus')
#                         Clade(branch_length=4.0, name='Silurus meridionalis')
#                         Clade(branch_length=4.0, name='Tachysurus vachellii')
#                         Clade(branch_length=4.0, name='Ictalurus furcatus')
#                         Clade(branch_length=4.0, name='Clarias gariepinus')
#                         Clade(branch_length=4.0, name='Ictalurus punctatus')
#                     Clade(branch_length=4.0, name='Characiformes')
#                         Clade(branch_length=4.0, name='Pygocentrus nattereri')
#                         Clade(branch_length=4.0, name='Hoplias malabaricus')
#                         Clade(branch_length=4.0, name='Astyanax mexicanus')
#                     Clade(branch_length=4.0, name='Cypriniformes')
#                         Clade(branch_length=4.0, name='Puntigrus tetrazona')
#                         Clade(branch_length=4.0, name='Triplophysa dalaica')
#                         Clade(branch_length=4.0, name='Danio aesculapii')
#                         Clade(branch_length=4.0, name='Triplophysa rosa')
#                         Clade(branch_length=4.0, name='Chanodichthys erythropterus')
#                         Clade(branch_length=4.0, name='Onychostoma macrolepis')
#                         Clade(branch_length=4.0, name='Carassius carassius')
#                         Clade(branch_length=4.0, name='Xyrauchen texanus')
#                         Clade(branch_length=4.0, name='Carassius gibelio')
#                         Clade(branch_length=4.0, name='Labeo rohita')
#                         Clade(branch_length=4.0, name='Megalobrama amblycephala')
#                         Clade(branch_length=4.0, name='Misgurnus anguillicaudatus')
#                         Clade(branch_length=4.0, name='Myxocyprinus asiaticus')
#                         Clade(branch_length=4.0, name='Pseudorasbora parva')
#                         Clade(branch_length=4.0, name='Cyprinus carpio')
#                         Clade(branch_length=4.0, name='Ctenopharyngodon idella')
#                         Clade(branch_length=4.0, name='Carassius auratus')
#                         Clade(branch_length=4.0, name='Danio rerio')
#                     Clade(branch_length=4.0, name='Clupeiformes')
#                         Clade(branch_length=4.0, name='Denticeps clupeoides')
#                         Clade(branch_length=4.0, name='Alosa alosa')
#                         Clade(branch_length=4.0, name='Engraulis encrasicolus')
#                         Clade(branch_length=4.0, name='Alosa sapidissima')
#                         Clade(branch_length=4.0, name='Sardina pilchardus')
#                         Clade(branch_length=4.0, name='Clupea harengus')
#                     Clade(branch_length=4.0, name='Anguilliformes')
#                         Clade(branch_length=4.0, name='Conger conger')
#                         Clade(branch_length=4.0, name='Anguilla rostrata')
#                         Clade(branch_length=4.0, name='Anguilla anguilla')
#                     Clade(branch_length=4.0, name='Amia calva')
#                     Clade(branch_length=4.0, name='Lepisosteus oculatus')
#                     Clade(branch_length=4.0, name='Acipenseriformes')
#                         Clade(branch_length=4.0, name='Polyodon spathula')
#                         Clade(branch_length=4.0, name='Acipenser ruthenus')
#                 Clade(branch_length=4.0, name='Latimeria chalumnae')
#                 Clade(branch_length=4.0, name='Protopterus annectens')
#                 Clade(branch_length=4.0, name='Chondrichthyes')
#                     Clade(branch_length=4.0, name='Pristis pectinata')
#                     Clade(branch_length=4.0, name='Heptranchias perlo')
#                     Clade(branch_length=4.0, name='Myliobatiformes')
#                         Clade(branch_length=4.0, name='Mobula hypostoma')
#                         Clade(branch_length=4.0, name='Hypanus sabinus')
#                     Clade(branch_length=4.0, name='Orectolobiformes')
#                         Clade(branch_length=4.0, name='Stegostoma tigrinum')
#                         Clade(branch_length=4.0, name='Rhincodon typus')
#                         Clade(branch_length=4.0, name='Hemiscyllium ocellatum')
#                         Clade(branch_length=4.0, name='Chiloscyllium plagiosum')
#                     Clade(branch_length=4.0, name='Carcharodon carcharias')
#                     Clade(branch_length=4.0, name='Scyliorhinus canicula')
#                     Clade(branch_length=4.0, name='Heterodontus francisci')
#                     Clade(branch_length=4.0, name='Rajiformes')
#                         Clade(branch_length=4.0, name='Amblyraja radiata')
#                         Clade(branch_length=4.0, name='Leucoraja erinaceus')
#                 Clade(branch_length=4.0, name='Myxine glutinosa')
#                 Clade(branch_length=4.0, name='Petromyzontiformes')
#                     Clade(branch_length=4.0, name='Petromyzon marinus')
#                     Clade(branch_length=4.0, name='Lethenteron reissneri')
#                 Clade(branch_length=4.0, name='Amphioxiformes')
#                     Clade(branch_length=4.0, name='Branchiostoma lanceolatum')
#                     Clade(branch_length=4.0, name='Branchiostoma floridae')
#                 Clade(branch_length=4.0, name='Ciona intestinalis')
#             Clade(branch_length=4.0, name='Echinodermata')
#                 Clade(branch_length=4.0, name='Temnopleuroida')
#                     Clade(branch_length=4.0, name='Lytechinus variegatus')
#                     Clade(branch_length=4.0, name='Lytechinus pictus')
#                 Clade(branch_length=4.0, name='Asterias rubens')
#             Clade(branch_length=4.0, name='Arthropoda')
#                 Clade(branch_length=4.0, name='Insecta')
#                     Clade(branch_length=4.0, name='Ischnura elegans')
#                     Clade(branch_length=4.0, name='Cloeon dipterum')
#                     Clade(branch_length=4.0, name='Chrysoperla carnea')
#                     Clade(branch_length=4.0, name='Bacillus rossius redtenbacheri')
#                     Clade(branch_length=4.0, name='Hymenoptera')
#                         Clade(branch_length=4.0, name='Neodiprion virginianus')
#                         Clade(branch_length=4.0, name='Neodiprion fabricii')
#                         Clade(branch_length=4.0, name='Belonocnema kinseyi')
#                         Clade(branch_length=4.0, name='Ooceraea biroi')
#                         Clade(branch_length=4.0, name='Osmia bicornis bicornis')
#                         Clade(branch_length=4.0, name='Cataglyphis hispanica')
#                         Clade(branch_length=4.0, name='Aphidius gifuensis')
#                         Clade(branch_length=4.0, name='Neodiprion pinetum')
#                         Clade(branch_length=4.0, name='Neodiprion lecontei')
#                         Clade(branch_length=4.0, name='Bombus pyrosoma')
#                         Clade(branch_length=4.0, name='Microplitis mediator')
#                         Clade(branch_length=4.0, name='Diprion similis')
#                         Clade(branch_length=4.0, name='Hylaeus volcanicus')
#                         Clade(branch_length=4.0, name='Bombus affinis')
#                         Clade(branch_length=4.0, name='Monomorium pharaonis')
#                         Clade(branch_length=4.0, name='Vespa velutina')
#                         Clade(branch_length=4.0, name='Bombus huntii')
#                         Clade(branch_length=4.0, name='Linepithema humile')
#                         Clade(branch_length=4.0, name='Microplitis demolitor')
#                         Clade(branch_length=4.0, name='Bombus pascuorum')
#                         Clade(branch_length=4.0, name='Diachasmimorpha longicaudata')
#                         Clade(branch_length=4.0, name='Athalia rosae')
#                         Clade(branch_length=4.0, name='Cotesia glomerata')
#                         Clade(branch_length=4.0, name='Venturia canescens')
#                         Clade(branch_length=4.0, name='Vespula pensylvanica')
#                         Clade(branch_length=4.0, name='Bombus terrestris')
#                         Clade(branch_length=4.0, name='Solenopsis invicta')
#                         Clade(branch_length=4.0, name='Apis cerana')
#                         Clade(branch_length=4.0, name='Apis mellifera')
#                         Clade(branch_length=4.0, name='Vespula vulgaris')
#                         Clade(branch_length=4.0, name='Vespa crabro')
#                         Clade(branch_length=4.0, name='Nasonia vitripennis')
#                     Clade(branch_length=4.0, name='Diptera')
#                         Clade(branch_length=4.0, name='Topomyia yanbarensis')
#                         Clade(branch_length=4.0, name='Anopheles marshallii')
#                         Clade(branch_length=4.0, name='Anopheles coluzzii')
#                         Clade(branch_length=4.0, name='Anopheles maculipalpis')
#                         Clade(branch_length=4.0, name='Drosophila subpulchrella')
#                         Clade(branch_length=4.0, name='Culicoides brevitarsis')
#                         Clade(branch_length=4.0, name='Anopheles ziemanni')
#                         Clade(branch_length=4.0, name='Hermetia illucens')
#                         Clade(branch_length=4.0, name='Toxorhynchites rutilus septentrionalis')
#                         Clade(branch_length=4.0, name='Malaya genurostris')
#                         Clade(branch_length=4.0, name='Eupeodes corollae')
#                         Clade(branch_length=4.0, name='Episyrphus balteatus')
#                         Clade(branch_length=4.0, name='Drosophila innubila')
#                         Clade(branch_length=4.0, name='Uranotaenia lowii')
#                         Clade(branch_length=4.0, name='Anopheles moucheti')
#                         Clade(branch_length=4.0, name='Anopheles nili')
#                         Clade(branch_length=4.0, name='Eurosta solidaginis')
#                         Clade(branch_length=4.0, name='Wyeomyia smithii')
#                         Clade(branch_length=4.0, name='Teleopsis dalmanni')
#                         Clade(branch_length=4.0, name='Anopheles bellator')
#                         Clade(branch_length=4.0, name='Anopheles coustani')
#                         Clade(branch_length=4.0, name='Drosophila santomea')
#                         Clade(branch_length=4.0, name='Drosophila biarmipes')
#                         Clade(branch_length=4.0, name='Armigeres subalbatus')
#                         Clade(branch_length=4.0, name='Drosophila gunungcola')
#                         Clade(branch_length=4.0, name='Bactrocera neohumeralis')
#                         Clade(branch_length=4.0, name='Anastrepha obliqua')
#                         Clade(branch_length=4.0, name='Drosophila sulfurigaster albostrigata')
#                         Clade(branch_length=4.0, name='Anopheles cruzii')
#                         Clade(branch_length=4.0, name='Anopheles funestus')
#                         Clade(branch_length=4.0, name='Bactrocera tryoni')
#                         Clade(branch_length=4.0, name='Sabethes cyaneus')
#                         Clade(branch_length=4.0, name='Anopheles darlingi')
#                         Clade(branch_length=4.0, name='Anopheles aquasalis')
#                         Clade(branch_length=4.0, name='Culex pipiens pallens')
#                         Clade(branch_length=4.0, name='Drosophila nasuta')
#                         Clade(branch_length=4.0, name='Bradysia coprophila')
#                         Clade(branch_length=4.0, name='Stomoxys calcitrans')
#                         Clade(branch_length=4.0, name='Anopheles stephensi')
#                         Clade(branch_length=4.0, name='Anopheles merus')
#                         Clade(branch_length=4.0, name='Drosophila busckii')
#                         Clade(branch_length=4.0, name='Phlebotomus papatasi')
#                         Clade(branch_length=4.0, name='Zeugodacus cucurbitae')
#                         Clade(branch_length=4.0, name='Anastrepha ludens')
#                         Clade(branch_length=4.0, name='Drosophila suzukii')
#                         Clade(branch_length=4.0, name='Bactrocera dorsalis')
#                         Clade(branch_length=4.0, name='Lucilia cuprina')
#                         Clade(branch_length=4.0, name='Calliphora vicina')
#                         Clade(branch_length=4.0, name='Drosophila albomicans')
#                         Clade(branch_length=4.0, name='Drosophila willistoni')
#                         Clade(branch_length=4.0, name='Drosophila yakuba')
#                         Clade(branch_length=4.0, name='Drosophila teissieri')
#                         Clade(branch_length=4.0, name='Drosophila subobscura')
#                         Clade(branch_length=4.0, name='Drosophila simulans')
#                         Clade(branch_length=4.0, name='Drosophila sechellia')
#                         Clade(branch_length=4.0, name='Drosophila pseudoobscura')
#                         Clade(branch_length=4.0, name='Drosophila miranda')
#                         Clade(branch_length=4.0, name='Drosophila mauritiana')
#                         Clade(branch_length=4.0, name='Drosophila ananassae')
#                         Clade(branch_length=4.0, name='Lutzomyia longipalpis')
#                         Clade(branch_length=4.0, name='Culex quinquefasciatus')
#                         Clade(branch_length=4.0, name='Anopheles arabiensis')
#                         Clade(branch_length=4.0, name='Anopheles albimanus')
#                         Clade(branch_length=4.0, name='Anopheles gambiae')
#                         Clade(branch_length=4.0, name='Aedes albopictus')
#                         Clade(branch_length=4.0, name='Aedes aegypti')
#                     Clade(branch_length=4.0, name='Lepidoptera')
#                         Clade(branch_length=4.0, name='Maniola hyperantus')
#                         Clade(branch_length=4.0, name='Cydia amplana')
#                         Clade(branch_length=4.0, name='Cydia fagiglandana')
#                         Clade(branch_length=4.0, name='Cydia strobilella')
#                         Clade(branch_length=4.0, name='Cydia splendana')
#                         Clade(branch_length=4.0, name='Leguminivora glycinivorella')
#                         Clade(branch_length=4.0, name='Amyelois transitella')
#                         Clade(branch_length=4.0, name='Vanessa tameamea')
#                         Clade(branch_length=4.0, name='Maniola jurtina')
#                         Clade(branch_length=4.0, name='Leptidea sinapis')
#                         Clade(branch_length=4.0, name='Vanessa cardui')
#                         Clade(branch_length=4.0, name='Nymphalis io')
#                         Clade(branch_length=4.0, name='Pararge aegeria')
# ...
#                         Clade(branch_length=4.0, name='Schistocerca nitens')
#                         Clade(branch_length=4.0, name='Schistocerca gregaria')
#                         Clade(branch_length=4.0, name='Schistocerca americana')
#                 Clade(branch_length=4.0, name='Arachnida')
#                     Clade(branch_length=4.0, name='Araneae')
#                         Clade(branch_length=4.0, name='Uloborus diversus')
#                         Clade(branch_length=4.0, name='Argiope bruennichi')
#                     Clade(branch_length=4.0, name='Ixodida')
#                         Clade(branch_length=4.0, name='Dermacentor silvarum')
#                         Clade(branch_length=4.0, name='Rhipicephalus sanguineus')
#                         Clade(branch_length=4.0, name='Ornithodoros turicata')
#                         Clade(branch_length=4.0, name='Rhipicephalus microplus')
#                 Clade(branch_length=4.0, name='Hexanauplia')
#                     Clade(branch_length=4.0, name='Lepeophtheirus salmonis')
#                     Clade(branch_length=4.0, name='Tigriopus californicus')
#                 Clade(branch_length=4.0, name='Decapoda')
#                     Clade(branch_length=4.0, name='Palaemon carinicauda')
#                     Clade(branch_length=4.0, name='Portunus trituberculatus')
#                     Clade(branch_length=4.0, name='Macrobrachium nipponense')
#                     Clade(branch_length=4.0, name='Penaeus chinensis')
#                     Clade(branch_length=4.0, name='Eriocheir sinensis')
#                     Clade(branch_length=4.0, name='Scylla paramamosain')
#                     Clade(branch_length=4.0, name='Macrobrachium rosenbergii')
#                     Clade(branch_length=4.0, name='Cherax quadricarinatus')
#                     Clade(branch_length=4.0, name='Procambarus clarkii')
#                     Clade(branch_length=4.0, name='Penaeus monodon')
#                 Clade(branch_length=4.0, name='Branchiopoda')
#                     Clade(branch_length=4.0, name='Diplostraca')
#                         Clade(branch_length=4.0, name='Daphnia carinata')
#                         Clade(branch_length=4.0, name='Daphnia magna')
#                         Clade(branch_length=4.0, name='Daphnia pulicaria')
#                         Clade(branch_length=4.0, name='Daphnia pulex')
#                     Clade(branch_length=4.0, name='Artemia franciscana')
#             Clade(branch_length=4.0, name='Mollusca')
#                 Clade(branch_length=4.0, name='Octopoda')
#                     Clade(branch_length=4.0, name='Octopus sinensis')
#                     Clade(branch_length=4.0, name='Octopus bimaculoides')
#                 Clade(branch_length=4.0, name='Liolophura japonica')
#                 Clade(branch_length=4.0, name='Bivalvia')
#                     Clade(branch_length=4.0, name='Myida')
#                         Clade(branch_length=4.0, name='Dreissena polymorpha')
#                         Clade(branch_length=4.0, name='Mya arenaria')
#                     Clade(branch_length=4.0, name='Mercenaria mercenaria')
#                     Clade(branch_length=4.0, name='Pectinida')
#                         Clade(branch_length=4.0, name='Argopecten irradians')
#                         Clade(branch_length=4.0, name='Pecten maximus')
#                     Clade(branch_length=4.0, name='Ostreida')
#                         Clade(branch_length=4.0, name='Magallana angulata')
#                         Clade(branch_length=4.0, name='Ostrea edulis')
#                         Clade(branch_length=4.0, name='Magallana gigas')
#                         Clade(branch_length=4.0, name='Crassostrea virginica')
#                     Clade(branch_length=4.0, name='Mytilus trossulus')
#                 Clade(branch_length=4.0, name='Gastropoda')
#                     Clade(branch_length=4.0, name='Gigantopelta aegis')
#                     Clade(branch_length=4.0, name='Pomacea canaliculata')
#                     Clade(branch_length=4.0, name='Haliotis asinina')
#                     Clade(branch_length=4.0, name='Biomphalaria glabrata')
#                     Clade(branch_length=4.0, name='Patella vulgata')
#             Clade(branch_length=4.0, name='Cnidaria')
#                 Clade(branch_length=4.0, name='Anthozoa')
#                     Clade(branch_length=4.0, name='Nematostella vectensis')
#                     Clade(branch_length=4.0, name='Scleractinia')
#                         Clade(branch_length=4.0, name='Montipora foliosa')
#                         Clade(branch_length=4.0, name='Montipora capricornis')
#                         Clade(branch_length=4.0, name='Pocillopora verrucosa')
#                         Clade(branch_length=4.0, name='Acropora muricata')
#                         Clade(branch_length=4.0, name='Acropora millepora')
#                 Clade(branch_length=4.0, name='Anthoathecata')
#                     Clade(branch_length=4.0, name='Hydractinia symbiolongicarpus')
#                     Clade(branch_length=4.0, name='Hydra vulgaris')
#             Clade(branch_length=4.0, name='Porifera')
#                 Clade(branch_length=4.0, name='Homosclerophorida')
#                     Clade(branch_length=4.0, name='Oscarella lobularis')
#                     Clade(branch_length=4.0, name='Corticium candelabrum')
#                 Clade(branch_length=4.0, name='Sycon ciliatum')
#                 Clade(branch_length=4.0, name='Demospongiae')
#                     Clade(branch_length=4.0, name='Dysidea avara')
#                     Clade(branch_length=4.0, name='Halichondria panicea')
#         Clade(branch_length=4.0, name='Streptophyta')
#             Clade(branch_length=4.0, name='Cryptomeria japonica')
#             Clade(branch_length=4.0, name='Physcomitrium patens')
#             Clade(branch_length=4.0, name='Magnoliopsida')
#                 Clade(branch_length=4.0, name='Tripterygium wilfordii')
#                 Clade(branch_length=4.0, name='Malania oleifera')
#                 Clade(branch_length=4.0, name='Nymphaea colorata')
#                 Clade(branch_length=4.0, name='Zingiberales')
#                     Clade(branch_length=4.0, name='Musa acuminata AAA Group')
#                     Clade(branch_length=4.0, name='Zingiber officinale')
#                 Clade(branch_length=4.0, name='Magnolia sinica')
#                 Clade(branch_length=4.0, name='Daucus carota subsp. sativus')
#                 Clade(branch_length=4.0, name='Dioscorea cayenensis subsp. rotundata')
#                 Clade(branch_length=4.0, name='Ericales')
#                     Clade(branch_length=4.0, name='Impatiens glandulifera')
#                     Clade(branch_length=4.0, name='Rhododendron vialii')
#                     Clade(branch_length=4.0, name='Actinidia eriantha')
#                     Clade(branch_length=4.0, name='Diospyros lotus')
#                 Clade(branch_length=4.0, name='Proteales')
#                     Clade(branch_length=4.0, name='Macadamia integrifolia')
#                     Clade(branch_length=4.0, name='Telopea speciosissima')
#                 Clade(branch_length=4.0, name='Arecales')
#                     Clade(branch_length=4.0, name='Elaeis guineensis')
#                     Clade(branch_length=4.0, name='Phoenix dactylifera')
#                 Clade(branch_length=4.0, name='Vitales')
#                     Clade(branch_length=4.0, name='Vitis riparia')
#                     Clade(branch_length=4.0, name='Vitis vinifera')
#                 Clade(branch_length=4.0, name='Myrtales')
#                     Clade(branch_length=4.0, name='Rhodamnia argentea')
#                     Clade(branch_length=4.0, name='Eucalyptus grandis')
#                     Clade(branch_length=4.0, name='Punica granatum')
#                 Clade(branch_length=4.0, name='Gentianales')
#                     Clade(branch_length=4.0, name='Coffea eugenioides')
#                     Clade(branch_length=4.0, name='Coffea arabica')
#                 Clade(branch_length=4.0, name='Asparagus officinalis')
#                 Clade(branch_length=4.0, name='Poales')
#                     Clade(branch_length=4.0, name='Panicum hallii')
#                     Clade(branch_length=4.0, name='Aegilops tauschii subsp. strangulata')
#                     Clade(branch_length=4.0, name='Miscanthus floridulus')
#                     Clade(branch_length=4.0, name='Hordeum vulgare subsp. vulgare')
#                     Clade(branch_length=4.0, name='Lolium rigidum')
#                     Clade(branch_length=4.0, name='Triticum dicoccoides')
#                     Clade(branch_length=4.0, name='Oryza sativa Japonica Group')
#                     Clade(branch_length=4.0, name='Panicum virgatum')
#                     Clade(branch_length=4.0, name='Phragmites australis')
#                     Clade(branch_length=4.0, name='Brachypodium distachyon')
#                     Clade(branch_length=4.0, name='Ananas comosus')
#                     Clade(branch_length=4.0, name='Zea mays')
#                     Clade(branch_length=4.0, name='Triticum urartu')
#                     Clade(branch_length=4.0, name='Triticum aestivum')
#                     Clade(branch_length=4.0, name='Sorghum bicolor')
#                     Clade(branch_length=4.0, name='Setaria viridis')
#                     Clade(branch_length=4.0, name='Setaria italica')
#                     Clade(branch_length=4.0, name='Oryza glaberrima')
#                     Clade(branch_length=4.0, name='Oryza brachyantha')
#                     Clade(branch_length=4.0, name='Lolium perenne')
#                 Clade(branch_length=4.0, name='Asterales')
#                     Clade(branch_length=4.0, name='Erigeron canadensis')
#                     Clade(branch_length=4.0, name='Cynara cardunculus var. scolymus')
#                     Clade(branch_length=4.0, name='Lactuca sativa')
#                     Clade(branch_length=4.0, name='Helianthus annuus')
#                 Clade(branch_length=4.0, name='Lamiales')
#                     Clade(branch_length=4.0, name='Salvia miltiorrhiza')
#                     Clade(branch_length=4.0, name='Salvia splendens')
#                     Clade(branch_length=4.0, name='Olea europaea var. sylvestris')
#                     Clade(branch_length=4.0, name='Salvia hispanica')
#                     Clade(branch_length=4.0, name='Sesamum indicum')
#                 Clade(branch_length=4.0, name='Solanales')
#                     Clade(branch_length=4.0, name='Solanum stenotomum')
#                     Clade(branch_length=4.0, name='Lycium ferocissimum')
#                     Clade(branch_length=4.0, name='Lycium barbarum')
#                     Clade(branch_length=4.0, name='Nicotiana attenuata')
#                     Clade(branch_length=4.0, name='Solanum dulcamara')
#                     Clade(branch_length=4.0, name='Ipomoea triloba')
#                     Clade(branch_length=4.0, name='Solanum pennellii')
#                     Clade(branch_length=4.0, name='Solanum lycopersicum')
#                     Clade(branch_length=4.0, name='Capsicum annuum')
#                 Clade(branch_length=4.0, name='Fabales')
#                     Clade(branch_length=4.0, name='Arachis stenosperma')
#                     Clade(branch_length=4.0, name='Arachis ipaensis')
#                     Clade(branch_length=4.0, name='Arachis duranensis')
#                     Clade(branch_length=4.0, name='Trifolium pratense')
#                     Clade(branch_length=4.0, name='Lotus japonicus')
#                     Clade(branch_length=4.0, name='Vigna unguiculata')
#                     Clade(branch_length=4.0, name='Vigna radiata var. radiata')
#                     Clade(branch_length=4.0, name='Vigna angularis')
#                     Clade(branch_length=4.0, name='Vicia villosa')
#                     Clade(branch_length=4.0, name='Pisum sativum')
#                     Clade(branch_length=4.0, name='Phaseolus vulgaris')
#                     Clade(branch_length=4.0, name='Medicago truncatula')
#                     Clade(branch_length=4.0, name='Lupinus angustifolius')
#                     Clade(branch_length=4.0, name='Glycine soja')
#                     Clade(branch_length=4.0, name='Glycine max')
#                     Clade(branch_length=4.0, name='Cicer arietinum')
#                     Clade(branch_length=4.0, name='Cajanus cajan')
#                     Clade(branch_length=4.0, name='Arachis hypogaea')
#                 Clade(branch_length=4.0, name='Brassicales')
#                     Clade(branch_length=4.0, name='Brassica oleracea var. oleracea')
#                     Clade(branch_length=4.0, name='Camelina sativa')
#                     Clade(branch_length=4.0, name='Raphanus sativus')
#                     Clade(branch_length=4.0, name='Brassica rapa')
#                     Clade(branch_length=4.0, name='Brassica napus')
#                 Clade(branch_length=4.0, name='Malpighiales')
#                     Clade(branch_length=4.0, name='Euphorbia lathyris')
#                     Clade(branch_length=4.0, name='Ricinus communis')
#                     Clade(branch_length=4.0, name='Mercurialis annua')
#                     Clade(branch_length=4.0, name='Manihot esculenta')
#                     Clade(branch_length=4.0, name='Hevea brasiliensis')
#                     Clade(branch_length=4.0, name='Populus trichocarpa')
#                     Clade(branch_length=4.0, name='Populus nigra')
#                 Clade(branch_length=4.0, name='Cucurbitales')
#                     Clade(branch_length=4.0, name='Benincasa hispida')
#                     Clade(branch_length=4.0, name='Cucurbita pepo subsp. pepo')
#                     Clade(branch_length=4.0, name='Cucumis sativus')
#                     Clade(branch_length=4.0, name='Cucumis melo')
#                 Clade(branch_length=4.0, name='Malvales')
#                     Clade(branch_length=4.0, name='Gossypium raimondii')
#                     Clade(branch_length=4.0, name='Gossypium arboreum')
#                     Clade(branch_length=4.0, name='Theobroma cacao')
#                     Clade(branch_length=4.0, name='Gossypium hirsutum')
#                 Clade(branch_length=4.0, name='Caryophyllales')
#                     Clade(branch_length=4.0, name='Amaranthus tricolor')
#                     Clade(branch_length=4.0, name='Spinacia oleracea')
#                     Clade(branch_length=4.0, name='Beta vulgaris subsp. vulgaris')
#                 Clade(branch_length=4.0, name='Fagales')
#                     Clade(branch_length=4.0, name='Juglans microcarpa x Juglans regia')
#                     Clade(branch_length=4.0, name='Quercus lobata')
#                     Clade(branch_length=4.0, name='Juglans regia')
#                     Clade(branch_length=4.0, name='Quercus robur')
#                     Clade(branch_length=4.0, name='Carya illinoinensis')
#                     Clade(branch_length=4.0, name='Corylus avellana')
#                     Clade(branch_length=4.0, name='Alnus glutinosa')
#                 Clade(branch_length=4.0, name='Rosales')
#                     Clade(branch_length=4.0, name='Ziziphus jujuba')
#                     Clade(branch_length=4.0, name='Prunus mume')
#                     Clade(branch_length=4.0, name='Fragaria vesca subsp. vesca')
#                     Clade(branch_length=4.0, name='Rosa chinensis')
#                     Clade(branch_length=4.0, name='Rosa rugosa')
#                     Clade(branch_length=4.0, name='Argentina anserina')
#                     Clade(branch_length=4.0, name='Pyrus communis')
#                     Clade(branch_length=4.0, name='Prunus persica')
#                     Clade(branch_length=4.0, name='Prunus dulcis')
#                     Clade(branch_length=4.0, name='Malus sylvestris')
#                     Clade(branch_length=4.0, name='Malus domestica')
#                     Clade(branch_length=4.0, name='Humulus lupulus')
#                     Clade(branch_length=4.0, name='Cannabis sativa')
#                 Clade(branch_length=4.0, name='Papaver somniferum')
#                 Clade(branch_length=4.0, name='Sapindales')
#                     Clade(branch_length=4.0, name='Mangifera indica')
#                     Clade(branch_length=4.0, name='Citrus sinensis')

# %%
prueba = refseq_bacteria_assembly.iloc[:2]
prueba.to_csv('prueba.csv', sep='\t')
